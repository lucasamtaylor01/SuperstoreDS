# %%
from pathlib import Path

import pandas as pd
import plotly.express as px

# %% [markdown]
# **OBSERVAÇÃO*

# %%
data_file = Path('..') / 'data' / 'data_processed' / 'SUPERSTORE_TRATADO.csv'
df = pd.read_csv(data_file, sep=',')

# %%
df.head()
# Out:
#    ORDER_DATE   SHIP_DATE       SHIP_MODE CUSTOMER_ID      SEGMENT COUNTRY  \
# 0  2019-01-03  2019-01-07  STANDARD CLASS    DP-13000     CONSUMER     USA
# 1  2019-01-04  2019-01-08  STANDARD CLASS    PO-19195  HOME OFFICE     USA
# 2  2019-01-05  2019-01-12  STANDARD CLASS    MB-18085     CONSUMER     USA
# 3  2019-01-06  2019-01-10  STANDARD CLASS    ME-17320  HOME OFFICE     USA
# 4  2019-01-06  2019-01-07     FIRST CLASS    JO-15145    CORPORATE     USA
#
#            CITY STATE   REGION       PRODUCT_ID         CATEGORY SUB_CATEGORY  \
# 0       HOUSTON    TX  CENTRAL  OFF-PA-10000174  OFFICE SUPPLIES        PAPER
# 1    NAPERVILLE    IL  CENTRAL  OFF-LA-10003223  OFFICE SUPPLIES       LABELS
# 2  PHILADELPHIA    PA     EAST  OFF-AR-10003478  OFFICE SUPPLIES          ART
# 3     HENDERSON    KY    SOUTH  OFF-AR-10001662  OFFICE SUPPLIES          ART
# 4        ATHENS    GA    SOUTH  OFF-AR-10002399  OFFICE SUPPLIES          ART
#
#                                         PRODUCT_NAME  PROFIT  NET_SALES
# 0  MESSAGE BOOK, WIREBOUND, FOUR 5 1/2" X 4" FORM...  5.5512    26.3168
# 1                                          AVERY 508  4.2717    28.2816
# 2  AVERY HI-LITER EVERBOLD PEN STYLE FLUORESCENT ...  4.8840    46.8864
# 3            ROGERS HANDHELD BARREL PENCIL SHARPENER  1.4796    10.9600
# 4  DIXON PRANG WATERCOLOR PENCILS, 10-COLOR SET W...  5.2398    38.3400

# %%
px.histogram(
    df,
    x='ORDER_DATE',
    y='PROFIT',
)

# %%
px.histogram(
    df,
    x='ORDER_DATE',
    y='NET_SALES',
)
